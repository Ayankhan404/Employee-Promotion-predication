# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("employeePromotion.csv")
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
df.shape
# Out:
# (54808, 14)

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df.isna().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#get the percentage in eduction  columns
df['education'].value_counts(normalize=True)*100
# Out:
# Bachelor's          69.980343
# Master's & above    28.483368
# Below Secondary      1.536289
# Name: education, dtype: float64

# %%
df['education'].isna().value_counts(normalize=True)*100
# Out:
# False    95.604656
# True      4.395344
# Name: education, dtype: float64

# %%
df['previous_year_rating'].isna().value_counts(normalize=True)*100
# Out:
# False    92.475551
# True      7.524449
# Name: previous_year_rating, dtype: float64

# %%
((df.isna().sum()/df.shape[0])*100)
# Out:
# employee_id             0.000000
# department              0.000000
# region                  0.000000
# education               4.395344
# gender                  0.000000
# recruitment_channel     0.000000
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    7.524449
# length_of_service       0.000000
# KPIs_met >80%           0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64

# %%
df['department'].value_counts()
# Out:
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: department, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region_2     12343
# region_22     6428
# region_7      4843
# region_15     2808
# region_13     2648
# region_26     2260
# region_31     1935
# region_4      1703
# region_27     1659
# region_16     1465
# region_28     1318
# region_11     1315
# region_23     1175
# region_29      994
# region_32      945
# region_19      874
# region_20      850
# region_14      827
# region_25      819
# region_17      796
# region_5       766
# region_6       690
# region_30      657
# region_8       655
# region_10      648
# region_1       610
# region_24      508
# region_12      500
# region_9       420
# region_21      411
# region_3       346
# region_34      292
# region_33      269
# region_18       31
# Name: region, dtype: int64

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
df.drop(columns='employee_id').describe()
# Out:
#        no_of_trainings           age  previous_year_rating  length_of_service  \
# count     54808.000000  54808.000000          50684.000000       54808.000000
# mean          1.253011     34.803915              3.329256           5.865512
# std           0.609264      7.660169              1.259993           4.265094
# min           1.000000     20.000000              1.000000           1.000000
# 25%           1.000000     29.000000              3.000000           3.000000
# 50%           1.000000     33.000000              3.000000           5.000000
# 75%           1.000000     39.000000              4.000000           7.000000
# max          10.000000     60.000000              5.000000          37.000000
#
#        KPIs_met >80%   awards_won?  avg_training_score   is_promoted
# count   54808.000000  54808.000000        54808.000000  54808.000000
# mean        0.351974      0.023172           63.386750      0.085170
# ...

# %%
# desctiption of categorical columns
df.describe(include='object')
# Out:
#                department    region   education gender recruitment_channel
# count               54808     54808       52399  54808               54808
# unique                  9        34           3      2                   3
# top     Sales & Marketing  region_2  Bachelor's      m               other
# freq                16840     12343       36669  38496               30446

# %%
plt.figure(figsize=(12,5))

# Countplot
plt.subplot(1,2,1)
sns.countplot(x=df['is_promoted'])
plt.xlabel("Promoted or Not")
plt.title("Promotion Distribution (Count)")

# Pie Chart
plt.subplot(1,2,2)
df['is_promoted'].value_counts().plot(kind='pie', 
                                      explode=[0, 0.1], 
                                      autopct='%1.1f%%', 
                                      startangle=90, 
                                      labels=df['is_promoted'].value_counts().index)
plt.ylabel("")
plt.title("Promotion Distribution (Pie)")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### we need to handle target columns

# %%
## fill missing values
df['education']= df['education'].fillna(df['education'].mode()[0])
df['previous_year_rating']= df['previous_year_rating'].fillna(df['previous_year_rating'].mode()[0])

# %%
df.isna().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             54808 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  54808 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df.select_dtypes('number').head()
# Out:
#    employee_id  no_of_trainings  age  previous_year_rating  length_of_service  \
# 0        65438                1   35                   5.0                  8
# 1        65141                1   30                   5.0                  4
# 2         7513                1   34                   3.0                  7
# 3         2542                2   39                   1.0                 10
# 4        48945                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# 0              1            0                  49            0
# 1              0            0                  60            0
# 2              0            0                  50            0
# 3              0            0                  50            0
# 4              0            0                  73            0

# %%
plt.subplot(1,2,1)
sns.boxplot(df['avg_training_score'])
plt.xlabel('Avrage Training Score')
plt.ylabel('Range')

plt.subplot(1,2,2)
sns.boxplot(df['length_of_service'])
plt.xlabel('length of the services')
plt.ylabel('Range')
plt.suptitle("box plot of outliner Detection")
plt.show()

# %%
df= df[df['length_of_service']<13]

# %%
plt.subplot(1,2,1)
sns.boxplot(df['avg_training_score'])
plt.xlabel('Avrage Training Score')
plt.ylabel('Range')

plt.subplot(1,2,2)
sns.boxplot(df['length_of_service'])
plt.xlabel('length of the services')
plt.ylabel('Range')
plt.suptitle("box plot of outliner Detection")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50632 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           50632 non-null  int64
#  1   department            50632 non-null  object
#  2   region                50632 non-null  object
#  3   education             50632 non-null  object
#  4   gender                50632 non-null  object
#  5   recruitment_channel   50632 non-null  object
#  6   no_of_trainings       50632 non-null  int64
#  7   age                   50632 non-null  int64
#  8   previous_year_rating  50632 non-null  float64
#  9   length_of_service     50632 non-null  int64
#  10  KPIs_met >80%         50632 non-null  int64
#  11  awards_won?           50632 non-null  int64
#  12  avg_training_score    50632 non-null  int64
#  13  is_promoted           50632 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

# KPI Met >80%
plt.subplot(1, 3, 1)
size = df['KPIs_met >80%'].value_counts()
labels = size.index.astype(str)  # Ensure labels match index
explode = [0, 0]
plt.pie(size, labels=labels, explode=explode, shadow=True, autopct='%1.1f%%', startangle=90)
plt.title('KPIs_met >80%')

# Previous Year Rating
plt.subplot(1, 3, 2)
size = df['previous_year_rating'].value_counts()
labels = size.index.astype(str)  # Ensure labels match index
explode = [0, 0, 0, 0, 0.1] if len(size) == 5 else [0] * len(size)  # Adjust dynamically
plt.pie(size, labels=labels, explode=explode, shadow=True, autopct='%1.1f%%', startangle=90)
plt.title('Previous Year Rating')

# Awards Won?
plt.subplot(1, 3, 3)
size = df['awards_won?'].value_counts()
labels = size.index.astype(str)
explode = [0, 0.1]
plt.pie(size, labels=labels, explode=explode, shadow=True, autopct='%1.1f%%', startangle=90)
plt.title('Awards Won?')

plt.tight_layout()
plt.show()

# %%
sns.countplot(x=df['no_of_trainings'], palette='spring')
plt.ylabel("Distribution of training data taken by employees")
plt.xlabel(None)  # Removes x-axis label
plt.title("Number of Trainings Distribution")
plt.show()

# %%
plt.hist(df['age'])
plt.title('Distribution of thew age in the company')
plt.xlabel("Age of the Employee")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=df['department'], palette='spring')
plt.title("Distribution of department")
plt.show()

# %%
plt.figure(figsize=(18, 6))  # Adjust width if needed
sns.countplot(x=df['region'], palette='spring')
plt.title("Distribution of Region", fontsize=14)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel("Region")
plt.ylabel("Count")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

# Education Pie Chart
plt.subplot(1, 3, 1)
size = df['education'].value_counts()
labels = size.index.astype(str)  # Convert labels to strings
explode = [0] * (len(size) - 1) + [0.1]  # Ensure last segment is exploded
plt.pie(size, labels=labels, explode=explode, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('Education')

# Gender Pie Chart
plt.subplot(1, 3, 2)
size = df['gender'].value_counts()
labels = size.index.astype(str)
explode = [0, 0]  # No explosion needed
plt.pie(size, labels=labels, explode=explode, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('Gender')

# Recruitment Channel Pie Chart
plt.subplot(1, 3, 3)
size = df['recruitment_channel'].value_counts()
labels = size.index.astype(str)
explode = [0] * (len(size) - 1) + [0.1]  # Ensure last segment is exploded
plt.pie(size, labels=labels, explode=explode, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title('Recruitment Channel')

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# ## bivariate Analysis
# c & c
# c & n
# n & n

# %%
x = pd.crosstab(df['gender'],df['is_promoted'])
x.div(x.sum(1).astype(float),axis=0).plot(kind='bar',stacked=False)
plt.title("Effect of gender on Promothion")
plt.xlabel("")
plt.show()

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
x = pd.crosstab(df['department'],df['is_promoted'])
x.div(x.sum(1).astype(float),axis=0).plot(kind='bar',stacked=False)
plt.title("Effect of department on Promothion")
plt.xlabel("")
plt.show()

# %%
sns.boxenplot(x='is_promoted', y='age', data=df)
plt.title("Effect of Age on Promotion")
plt.xlabel("")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.title("Correlation")
# Out:
# C:\Users\foziya khan\AppData\Local\Temp\ipykernel_3016\682024381.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# Text(0.5, 1.0, 'Correlation')

# %%
df.head(1)
# Out:
#    employee_id         department    region         education gender  \
# 0        65438  Sales & Marketing  region_7  Master's & above      f
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
#
#    is_promoted
# 0            0

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=df, x='department', y='avg_training_score', hue='gender')
plt.title("Chance of the promotion in each department whem they have won some award")
plt.xlabel("Department")
plt.ylabel("Promoted or not")
plt.show()

# %% [markdown]
# ## feature engineering

# %%
df['sum_metric']=df['awards_won?']+df['KPIs_met >80%']+df['previous_year_rating']

# creating total score columns
df['total_score']= df['avg_training_score']*df['no_of_trainings']

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
## remove unnassacary columns
df=df.drop(columns=['employee_id','region','recruitment_channel'],axis=1)

# %%
df[(df['KPIs_met >80%']==0)& (df['previous_year_rating']==1.0)& (df['awards_won?']==0) & (df['avg_training_score']<60) & (df['is_promoted']==1)]
# Out:
#               department   education gender  no_of_trainings  age  \
# 31860  Sales & Marketing  Bachelor's      m                1   27
# 51374  Sales & Marketing  Bachelor's      m                1   31
#
#        previous_year_rating  length_of_service  KPIs_met >80%  awards_won?  \
# 31860                   1.0                  2              0            0
# 51374                   1.0                  5              0            0
#
#        avg_training_score  is_promoted  sum_metric  total_score
# 31860                  58            1         1.0           58
# 51374                  58            1         1.0           58

# %%
df=df.drop(df[(df['KPIs_met >80%']==0)& (df['previous_year_rating']==1.0)& (df['awards_won?']==0) & (df['avg_training_score']<60) & (df['is_promoted']==1)].index)

# %%
df.shape
# Out:
# (50630, 13)

# %%
df.select_dtypes('object').head()
# Out:
#           department         education gender
# 0  Sales & Marketing  Master's & above      f
# 1         Operations        Bachelor's      m
# 2  Sales & Marketing        Bachelor's      m
# 3  Sales & Marketing        Bachelor's      m
# 4         Technology        Bachelor's      m

# %%
df['education'].value_counts()
# Out:
# Bachelor's          36963
# Master's & above    12862
# Below Secondary       805
# Name: education, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
df['education'].value_counts()
# Out:
# Bachelor's          36963
# Master's & above    12862
# Below Secondary       805
# Name: education, dtype: int64

# %%
le=LabelEncoder()
oe = OrdinalEncoder(categories=[["Below Secondary", "Bachelor's", "Master's & above"]])

# %%
df['gender']=le.fit_transform(df['gender'])
df['department']=le.fit_transform(df['department'])

# %%
df['education'] = oe.fit_transform(df[['education']])

# %%
df.head()
# Out:
#    department  education  gender  no_of_trainings  age  previous_year_rating  \
# 0           7        2.0       0                1   35                   5.0
# 1           4        1.0       1                1   30                   5.0
# 2           7        1.0       1                1   34                   3.0
# 3           7        1.0       1                2   39                   1.0
# 4           8        1.0       1                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted  sum_metric  total_score
# 0            0         6.0           49
# ...

# %%
x=df.drop(columns='is_promoted')
y=df['is_promoted']

# %%
x.shape
# Out:
# (50630, 12)

# %%
y.shape
# Out:
# (50630,)

# %%
## handling Imblaced data
from imblearn.over_sampling import SMOTE

oversample=SMOTE()
x,y=oversample.fit_resample(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()

# %%
sc.fit(x_train)

# transform train and test sets
x_train= sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
model.score(x_train,y_train)
# Out:
# 0.991567909409078

# %%
model.score(x_test,y_test)
# Out:
# 0.9336792605805092

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[8517,  781],
#        [ 446, 8757]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
Rf =RandomForestClassifier()
Rf.fit(x_train,y_train)
y_pred_Rf=Rf.predict(x_test)

# %%
Rf.score(x_test,y_test)
# Out:
# 0.9495162423652775

# %%
cm = confusion_matrix(y_test,y_pred_Rf)
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
prediction=model.predict(np.array([[2,3,1,1,30,5,10,1,1,95,7,700]]))
prediction
# Out:
# array([1], dtype=int64)

# %%
Rf_pred=Rf.predict(np.array([[2,3,1,1,30,5,10,1,1,95,7,700]]))
Rf_pred
# Out:
# array([1], dtype=int64)
